# %%
import netCDF4
from netCDF4 import Dataset as Dataset

import numpy as np
import pandas as pd

import glob

import matplotlib as mpl
import matplotlib.pyplot as pyplot
import matplotlib.patches as mpatches
from mpl_toolkits.basemap import Basemap



pyplot.rcParams["font.family"] = "Arial"

# %%
rf = 'RF12'

dataset = Dataset('/Volumes/Hard Drive/2018 - SOCRATES/Data/Flight Level Data/'+ rf +'.nc')

lats = dataset['GGLAT'][:]
lons = dataset['GGLON'][:]
times = dataset['Time'][:]

times = netCDF4.num2date(times,units = 'seconds since 2018-01-19 00:00:00 +0000')

df = pd.DataFrame()
df['Lats'] = lats
df['Lons'] = lons

df.index = times

# %%
if rf == 'RF02':
    startT = '2018-01-19 01:33:00'
    endT = '2018-01-19 03:24:00'

if rf == 'RF03':
    startT = '2018-01-22 21:39:00'
    endT = '2018-01-22 23:44:00'

if rf == 'RF04':
    startT = '2018-01-24 00:06:00'
    endT = '2018-01-24 01:58:00'

if rf == 'RF05':
    startT = '2018-01-25 23:07:00'
    endT = '2018-01-26 00:46:00'

if rf == 'RF06':
    startT = '2018-01-28 23:40:00'
    endT = '2018-01-29 01:19:00'

if rf == 'RF07':
    startT = '2018-01-31 01:37:00'
    endT = '2018-01-31 03:15:00'

if rf == 'RF10':
    startT = '2018-02-07 21:30:00'
    endT = '2018-02-07 23:55:00'

if rf == 'RF11':
    startT = '2018-02-17 02:15:00'
    endT = '2018-02-17 03:02:00'

if rf == 'RF12':
    startT = '2018-02-18 00:30:00'
    endT = '2018-02-18 02:38:00'

if rf == 'RF13':
    startT = '2018-02-19 23:40:00'
    endT = '2018-02-20 01:30:00'

if rf == 'RF14':
    startT = '2018-02-21 23:18:00'
    endT = '2018-02-22 01:45:00'

if rf == 'RF15':
    startT = '2018-02-24 02:26:00'
    endT = '2018-02-24 03:52:00'

df = df.between_time(startT[11:], endT[11:])
df = df.dropna(axis = 0)

# %%
#RF02
if rf == 'RF02':
    a = pd.DataFrame([['2018-01-19 01:32:21', 6142.56, 145.8, -46.74],
                       ['2018-01-19 01:45:41', 6087.08, 145.06, -48.07],
                       ['2018-01-19 02:12:45', 5978.53, 143.46, -50.70],
                       ['2018-01-19 02:28:26', 5908.07, 143.05, -52.35],
                       ['2018-01-19 02:44:58', 5843.25, 142.58, -54.08],
                       ['2018-01-19 03:05:46', 5773.16, 141.93, -56.25],
                       ['2018-01-19 03:24:48', 5717.95, 141.11, -58.28]])
    a.columns = ['Time', 'Height', 'Lons', 'Lats']
    a['Time'] = pd.to_datetime(a['Time'])
    #pyplot.scatter(a['Time'], a['Height'],  marker=(5, 1), s = 200, c = 'red', edgecolors = 'black')
    
#RF03
if rf == 'RF03':
    a =  pd.DataFrame([['2018-01-22 21:37:52', 6015.93, 146.35, -46.13],
                       ['2018-01-22 22:27:06', 5689.80, 143.77, -51.02],
                       ['2018-01-22 22:47:55', 5607.87, 142.38, -53.02],
                       ['2018-01-22 22:58:23', 5587.34, 141.28, -53.51],
                       ['2018-01-22 23:20:34', 4988.54, 137.72, -53.58],
                       ['2018-01-22 23:36:18', 3529.19, 135.29, -53.54]])
    a.columns = ['Time', 'Height', 'Lons', 'Lats']
    a['Time'] = pd.to_datetime(a['Time'])
    #pyplot.scatter(a['Time'], a['Height'],  marker=(5, 1), s = 200, c = 'red', edgecolors = 'black')
    
#RF04
if rf == 'RF04':
    a =  pd.DataFrame([['2018-01-24 00:03:48', 5943.99, 146.02, -48.05],
                       ['2018-01-24 00:21:26', 5757.91, 145.36, -49.99],
                       ['2018-01-24 00:41:46', 5672.18, 144.09, -52.01],
                       ['2018-01-24 01:03:20', 5664.24, 142.29, -54.00],
                       ['2018-01-24 01:24:16', 5661.87, 140.35, -55.94],
                       ['2018-01-24 01:43:37', 5646.19, 140.21, -58.02],
                       ['2018-01-24 02:00:06', 5628.26, 140.17, -59.82]])
    a.columns = ['Time', 'Height', 'Lons', 'Lats']
    a['Time'] = pd.to_datetime(a['Time'])
    #pyplot.scatter(a['Time'], a['Height'],  marker=(5, 1), s = 200, c = 'red', edgecolors = 'black')
    
#RF05
if rf == 'RF05':
    a =  pd.DataFrame([['2018-01-25 23:06:08', 6276.35, 147.11, -43.93],
                       ['2018-01-25 23:45:58', 6120.87, 144.63, -48.01],
                       ['2018-01-26 02:42:50', 5998.40, 143.12, -50.00],
                       ['2018-01-26 00:27:14', 5875.73, 141.65, -52.00],
                       ['2018-01-26 00:48:21', 4747.96, 140.08, -53.99]])
    
    a.columns = ['Time', 'Height', 'Lons', 'Lats']
    a['Time'] = pd.to_datetime(a['Time'])
    #pyplot.scatter(a['Time'], a['Height'],  marker=(5, 1), s = 200, c = 'red', edgecolors = 'black')
    
#RF06
if rf == 'RF06':
    a =  pd.DataFrame([['2018-01-28 23:37:29', 6102.10, 146.89, -48.05],
                       ['2018-01-28 23:53:16', 5987.77, 146.46, -50.07],
                       ['2018-01-29 00:08:39', 5875.33, 146.02, -52.01],
                       ['2018-01-29 00:25:20', 5775.24, 145.54, -53.99],
                       ['2018-01-29 00:43:23', 5698.22, 144.98, -56.00],
                       ['2018-01-29 01:01:36', 5646.92, 144.39, -57.99],
                       ['2018-01-29 01:19:43', 5611.66, 143.74, -59.95]])
    a.columns = ['Time', 'Height', 'Lons', 'Lats']
    a['Time'] = pd.to_datetime(a['Time'])
    #pyplot.scatter(a['Time'], a['Height'],  marker=(5, 1), s = 200, c = 'red', edgecolors = 'black')
    
#RF07
if rf == 'RF07':
    a =  pd.DataFrame([['2018-01-31 02:25:00', 5935.74, 149.95, -45.69],
                       ['2018-01-31 01:53:32', 5914.48, 151.16, -47.03],
                       ['2018-01-31 02:17:36', 5894.38, 153.06, -48.99],
                       ['2018-01-31 02:40:49', 5860.10, 154.95, -51.00],
                       ['2018-01-31 03:03:58', 5803.21, 157.17, -53.12],
                       ['2018-01-31 03:13:00', 5760.80, 158.19, -54.46]])
    a.columns = ['Time', 'Height', 'Lons', 'Lats']
    a['Time'] = pd.to_datetime(a['Time'])
    #pyplot.scatter(a['Time'], a['Height'],  marker=(5, 1), s = 200, c = 'red', edgecolors = 'black')

#RF10
if rf == 'RF10':
    a =  pd.DataFrame([['2018-02-07 21:56:08', 6313.95, 145.53, -49.00],
                       ['2018-02-07 22:07:21', 6067.13, 145.00, -50.00],
                       ['2018-02-07 22:28:24', 6017.12, 145.00, -52.00],
                       ['2018-02-07 22:50:02', 5961.41, 145.00, -54.00],
                       ['2018-02-07 23:11:58', 5895.25, 145.00, -56.00],
                       ['2018-02-07 23:33:56', 5810.82, 145.00, -58.00],
                       ['2018-02-07 23:55:38', 5705.50, 145.00, -59.99]])
    a.columns = ['Time', 'Height', 'Lons', 'Lats']
    a['Time'] = pd.to_datetime(a['Time'])
    #pyplot.scatter(a['Time'], a['Height'],  marker=(5, 1), s = 200, c = 'red', edgecolors = 'black')

#RF11
if rf == 'RF11':
    a =  pd.DataFrame([['2018-02-17 02:12:12', 6017.46, 146.56, -46.00],
                       ['2018-02-17 02:21:34', 5967.50, 146.20, -47.00],
                       ['2018-02-17 02:31:25', 5909.52, 145.79, -48.05],
                       ['2018-02-17 02:40:10', 5856.09, 145.41, -48.99],
                       ['2018-02-17 02:44:30', 5830.46, 145.23, -49.45],
                       ['2018-02-17 02:50:38', 5399.84, 144.97, -50.06],
                       ['2018-02-17 03:02:58', 4212.38, 144.59, -51.04]])
    a.columns = ['Time', 'Height', 'Lons', 'Lats']
    a['Time'] = pd.to_datetime(a['Time'])
    #pyplot.scatter(a['Time'], a['Height'],  marker=(5, 1), s = 200, c = 'red', edgecolors = 'black')
    
    
#RF12
if rf == 'RF12':
    a =  pd.DataFrame([['2018-02-18 00:29:00', 6031, 146.72, -45.99],
                       ['2018-02-18 00:40:00', 5975, 146.36, -46.99],
                       ['2018-02-18 01:27:27', 5866.50, 144.78, -50.99],
                       ['2018-02-18 01:39:35', 5862.37, 144.34, -51.99],
                       ['2018-02-18 01:51:38', 5862.09, 143.93, -52.99],
                       ['2018-02-18 02:03:46', 5856.93, 143.63, -54.00],
                       ['2018-02-18 02:15:49', 5855.04, 143.32, -54.99],
                       ['2018-02-18 02:27:56', 5850.24, 142.99, -55.99],
                       ['2018-02-18 02:40:06', 5845, 142.64, -56.99]])
    a.columns = ['Time', 'Height', 'Lons', 'Lats']
    a['Time'] = pd.to_datetime(a['Time'])
    #pyplot.scatter(a['Time'], a['Height'],  marker=(5, 1), s = 200, c = 'red', edgecolors = 'black')
    
#RF13
if rf == 'RF13':
    a =  pd.DataFrame([['2018-02-19 23:39:42', 6300.37, 150.11, -46.06],
                       ['2018-02-19 23:53:11', 6285.22, 151.02, -47.13],
                       ['2018-02-20 00:06:16', 6272.79, 151.92, -48.15],
                       ['2018-02-20 00:19:32', 6255.77, 152.88, -49.17],
                       ['2018-02-20 00:30:30', 6247.35, 153.71, -49.99],
                       ['2018-02-20 00:43:51', 6230.19, 154.70, -50.99],
                       ['2018-02-20 00:57:26', 6213.19, 155.77, -51.99],
                       ['2018-02-20 01:11:04', 6193.08, 156.91, -53.00],
                       ['2018-02-20 01:30:18', 6166.06, 158.64, -54.42],
                       ['2018-02-20 01:31:38', 6163.58, 158.74, -54.52]])
    a.columns = ['Time', 'Height', 'Lons', 'Lats']
    a['Time'] = pd.to_datetime(a['Time'])
    #pyplot.scatter(a['Time'], a['Height'],  marker=(5, 1), s = 200, c = 'red', edgecolors = 'black')
    
    
#RF14
if rf == 'RF14':
    a =  pd.DataFrame([['2018-02-21 23:16:49', 6297.32, 147.36, -45.36],
                       ['2018-02-21 23:33:45', 6260.26, 147.15, -46.99],
                       ['2018-02-21 23:41:11', 6234.72, 147.05, -47.99],
                       ['2018-02-21 23:54:44', 6204.86, 146.95, -48.99],
                       ['2018-02-22 00:05:24', 6170.63, 146.84, -49.99],
                       ['2018-02-22 00:16:14', 6146.07, 146.73, -50.99],
                       ['2018-02-22 00:27:10', 6108.38, 146.62, -51.99],
                       ['2018-02-22 00:38:12', 6064.97, 146.50, -52.99],
                       ['2018-02-22 00:49:28', 6018.82, 146.37, -53.99],
                       ['2018-02-22 01:00:50', 5967.52, 146.24, -54.99],
                       ['2018-02-22 01:12:14', 5913.59, 146.31, -55.99],
                       ['2018-02-22 01:23:48', 5852.96, 146.55, -57.01],
                       ['2018-02-22 01:35:18', 5797.49, 146.77, -58.01],
                       ['2018-02-22 01:46:42', 5319.43, 147.08, -58.99]])
    a.columns = ['Time', 'Height', 'Lons', 'Lats']
    a['Time'] = pd.to_datetime(a['Time'])
    #pyplot.scatter(a['Time'], a['Height'],  marker=(5, 1), s = 200, c = 'red', edgecolors = 'black')
    

#RF15
if rf == 'RF15':
    a =  pd.DataFrame([['2018-02-24 02:25:00', 6084.35, 146.12, -43.79],
                       ['2018-02-24 02:33:14', 6048.91, 145.28, -44.21],
                       ['2018-02-24 02:42:50', 6006.66, 144.33, -44.65],
                       ['2018-02-24 02:52:54', 5967.14, 143.33, -45.11],
                       ['2018-02-24 03:02:58', 5928.93, 142.32, -45.55],
                       ['2018-02-24 03:13:00', 5905.43, 141.32, -45.98],
                       ['2018-02-24 03:23:00', 5907.61, 140.32, -46.39],
                       ['2018-02-24 03:33:00', 5926.61, 139.32, -46.78],
                       ['2018-02-24 03:43:00', 5960.95, 138.30, -47.18],
                       ['2018-02-24 03:53:00', 5991.54, 137.25, -47.56]])
    a.columns = ['Time', 'Height', 'Lons', 'Lats']
    a['Time'] = pd.to_datetime(a['Time'])
    #pyplot.scatter(a['Time'], a['Height'],  marker=(5, 1), s = 200, c = 'red', edgecolors = 'black')

ds = pd.DataFrame(a.values)
ds.columns = ['Time', 'Height', 'Lons', 'Lats']

# %%
filename = '/Volumes/Hard Drive/2018 - SOCRATES/Data/HIMAWARI Data/RF12/satellite.SATCORPS_HIMAWARI-8.201802180130.NC'

data = Dataset(filename)
    
date = filename[75:83]
time = filename[83:87]


endt = time[0:2] + ':' + time[2:5] + ':00'



fig = pyplot.figure(figsize=(10, 10))

lat_min = pd.DataFrame(data['latitude'][:]).min().min() + 5
lat_max = pd.DataFrame(data['latitude'][:]).max().max()
lon_min = pd.DataFrame(data['longitude'][:]).min().min()
lon_max = pd.DataFrame(data['longitude'][:]).max().max()


m = Basemap(projection = 'merc', llcrnrlat=lat_min, urcrnrlat=lat_max, llcrnrlon=lon_min, urcrnrlon=lon_max, resolution = 'l')
m.drawcoastlines()


lon, lat= m.makegrid(data['reflectance_vis'].shape[1],data['reflectance_vis'].shape[0])
x1, y1 = m(data['longitude'][:], data['latitude'][:])
myPLT = m.pcolor(x1,y1,np.sqrt(data['reflectance_vis']),  cmap = 'Greys_r', vmin = .2, vmax = 1.25, rasterized = True)


parallels = np.arange(-70., 40., 5.)
m.drawparallels(parallels,labels=[1,0,0,0],fontsize=22)

meridians = np.arange(130.,165.,5.)
m.drawmeridians(meridians,labels=[0,0,0,1],fontsize=22)


m.plot(df['Lons'].values, df['Lats'].values, linewidth = 8, color = 'black', latlon = True, alpha = .8)
m.plot(df['Lons'].values, df['Lats'].values, linewidth = 5, color = 'yellow', latlon = True, alpha = .8)


m.scatter(ds['Lons'].values, ds['Lats'].values, latlon = True, marker=(5, 1), s = 200, zorder = 10, c = 'red', edgecolors = 'black')


pyplot.xlabel('Longitude', labelpad = 30, fontsize = 28)
pyplot.ylabel('Latitude', labelpad = 50, fontsize = 28)
#pyplot.title('HIMAWARI Visible Reflectance ' + date + ' ' + time +'00', fontsize = 16)

cbar = pyplot.colorbar(myPLT, pad=0.01, aspect=40, fraction=0.046)
cbar.ax.tick_params(labelsize=22) 
cbar.set_label('Visible Reflectance (0.65 um)', fontsize = 28, labelpad=10)

pyplot.savefig('Desktop/' + rf + '_himawari_8_satellite.pdf', format = 'pdf', dpi = 300)



pyplot.show()
# Out:
# /Users/troyzaremba/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:21: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
# /Users/troyzaremba/opt/anaconda3/lib/python3.7/site-packages/numpy/ma/core.py:1015: RuntimeWarning: overflow encountered in multiply
#   result = self.f(da, db, *args, **kwargs)

# %%
fig = pyplot.figure(figsize=(10, 10))

m = Basemap(projection = 'merc', llcrnrlat=lat_min, urcrnrlat=lat_max, llcrnrlon=lon_min, urcrnrlon=lon_max, resolution = 'l')
m.drawcoastlines()


lon, lat= m.makegrid(data['cloud_top_temperature'].shape[1],data['cloud_top_temperature'].shape[0])
x1, y1 = m(data['longitude'][:], data['latitude'][:])
myPLT = m.pcolor(x1,y1,data['cloud_top_temperature'][:] - 273.15,  cmap = 'jet', vmin = -60, vmax = 20, rasterized = True)

m.plot(df['Lons'].values, df['Lats'].values, linewidth = 8, color = 'black', latlon = True, alpha = .8)
m.plot(df['Lons'].values, df['Lats'].values, linewidth = 5, color = 'yellow', latlon = True, alpha = .8)

m.scatter(ds['Lons'].values, ds['Lats'].values, latlon = True, marker=(5, 1), s = 200, zorder = 10, c = 'red', edgecolors = 'black')

parallels = np.arange(-70., 40., 5.)
m.drawparallels(parallels,labels=[1,0,0,0],fontsize=22)

meridians = np.arange(130.,165.,5.)
m.drawmeridians(meridians,labels=[0,0,0,1],fontsize=22)

pyplot.xlabel('Longitude', labelpad = 30, fontsize = 28)
pyplot.ylabel('Latitude', labelpad = 50, fontsize = 28)
#pyplot.title('HIMAWARI Visible Reflectance ' + date + ' ' + time +'00', fontsize = 16)

cbar = pyplot.colorbar(myPLT, pad=0.01, aspect=40, fraction=0.046)
cbar.ax.tick_params(labelsize=22) 
cbar.set_label('Cloud Top Temperature (Celsisus)', fontsize = 28, labelpad=10)

pyplot.savefig('Desktop/' + rf + '_himawari_8_satellite_ctt.pdf', format = 'pdf', dpi = 300)

pyplot.show()
# Out:
# /Users/troyzaremba/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/troyzaremba/opt/anaconda3/lib/python3.7/site-packages/numpy/ma/core.py:1015: RuntimeWarning: overflow encountered in multiply
#   result = self.f(da, db, *args, **kwargs)

# %%
fig = pyplot.figure(figsize=(10, 10))

m = Basemap(projection = 'merc', llcrnrlat=lat_min, urcrnrlat=lat_max, llcrnrlon=lon_min, urcrnrlon=lon_max, resolution = 'l')
m.drawcoastlines()


lon, lat= m.makegrid(data['cloud_top_height'].shape[1],data['cloud_top_height'].shape[0])
x1, y1 = m(data['longitude'][:], data['latitude'][:])
myPLT = m.pcolor(x1,y1,data['cloud_top_height'][:],  cmap = 'viridis', vmin = 0, vmax = 20, rasterized = True)

m.plot(df['Lons'].values, df['Lats'].values, linewidth = 8, color = 'black', latlon = True, alpha = .8)
m.plot(df['Lons'].values, df['Lats'].values, linewidth = 5, color = 'yellow', latlon = True, alpha = .8)

m.scatter(ds['Lons'].values, ds['Lats'].values, latlon = True, marker=(5, 1), s = 200, zorder = 10, c = 'red', edgecolors = 'black')

parallels = np.arange(-70., 40., 5.)
m.drawparallels(parallels,labels=[1,0,0,0],fontsize=22)

meridians = np.arange(130.,165.,5.)
m.drawmeridians(meridians,labels=[0,0,0,1],fontsize=22)

pyplot.xlabel('Longitude', labelpad = 30, fontsize = 28)
pyplot.ylabel('Latitude', labelpad = 50, fontsize = 28)

cbar = pyplot.colorbar(myPLT, pad=0.01, aspect=40, fraction=0.046)
cbar.ax.tick_params(labelsize=22) 
cbar.set_label('Cloud Top Height (km)', fontsize = 28, labelpad=10)

pyplot.savefig('Desktop/' + rf + '_himawari_8_satellite_cth.pdf', format = 'pdf', dpi = 300)

pyplot.show()
# Out:
# /Users/troyzaremba/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/troyzaremba/opt/anaconda3/lib/python3.7/site-packages/numpy/ma/core.py:1015: RuntimeWarning: overflow encountered in multiply
#   result = self.f(da, db, *args, **kwargs)

# %%
#0 - SNOW
#1 - WATER
#2 - ICE
#3 - NO RETRIEVAL
#4 - CLEAR
#5 - BAD DATA
#6 - SUSPECTED WATER
#7 - SUSPECTED ICE

fig = pyplot.figure(figsize=(14, 9))

m = Basemap(projection = 'merc', llcrnrlat=lat_min, urcrnrlat=lat_max, llcrnrlon=lon_min, urcrnrlon=lon_max, resolution = 'l')
m.drawcoastlines()

lon, lat= m.makegrid(data['cloud_phase'].shape[1],data['cloud_phase'].shape[0])
x1, y1 = m(data['longitude'][:], data['latitude'][:])
myPLT = m.pcolor(x1,y1,data['cloud_phase'],  cmap = pyplot.cm.get_cmap('cubehelix', 8), vmin = 0, vmax = 7)

m.plot(df['Lons'].values, df['Lats'].values, linewidth = 8, color = 'black', latlon = True, alpha = .8)
m.plot(df['Lons'].values, df['Lats'].values, linewidth = 5, color = 'yellow', latlon = True, alpha = .8)

m.scatter(ds['Lons'].values, ds['Lats'].values, latlon = True, marker=(5, 1), s = 200, zorder = 10, c = 'red', edgecolors = 'black')

parallels = np.arange(-70., 40., 5.)
m.drawparallels(parallels,labels=[1,0,0,0],fontsize=22)

meridians = np.arange(130.,165.,5.)
m.drawmeridians(meridians,labels=[0,0,0,1],fontsize=22)

pyplot.xlabel('Longitude', labelpad = 30, fontsize = 28)
pyplot.ylabel('Latitude', labelpad = 50, fontsize = 28)

pyplot.legend(handles=[color_snow, color_water, color_ice, color_no_retrieval, color_clear, color_bad_data, color_suspected_water, color_suspected_ice], loc='center left', bbox_to_anchor=(1, 0.5))

pyplot.show()
# Out:
# /Users/troyzaremba/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   if sys.path[0] == '':
